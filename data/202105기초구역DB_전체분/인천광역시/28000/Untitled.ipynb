# %%
import pandas as pd

# %%
df = pd.read_excel('./TL_KODIS_BAS.xlsx')
df
# Out:
#         BAS_AR  BAS_ID  BAS_MGT_SN CTP_KOR_NM   MVMN_DE       MVMN_RESN  \
# 0     0.051750   22405  2811000106      인천광역시  20161027  분할에 의한 기초구역 생성
# 1     0.782714   22377  2811000049      인천광역시  20161027  분할에 의한 기초구역 변경
# 2     0.804650   22378  2811000052      인천광역시  20161027  분할에 의한 기초구역 변경
# 3     1.004315   22389  2811000090      인천광역시  20161027  분할에 의한 기초구역 생성
# 4     0.253419   22390  2811000091      인천광역시  20161027  분할에 의한 기초구역 생성
# ...        ...     ...         ...        ...       ...             ...
# 1330  6.555269   23127  2872000035      인천광역시  20121221     국가기초구역 최초생성
# 1331  2.355923   23107  2872000009      인천광역시  20121221     국가기초구역 최초생성
# 1332  3.527996   23132  2872000010      인천광역시  20121221     국가기초구역 최초생성
# 1333  5.939951   23119  2872000016      인천광역시  20121221     국가기초구역 최초생성
# 1334  1.443820   23123  2872000013      인천광역시  20121221     국가기초구역 최초생성
#
#        NTFC_DE        OPERT_DE  SIG_CD SIG_KOR_NM
# 0     20161027  20161027000000   28110         중구
# ...

# %%
len(df.loc[df['SIG_CD']==28237])
# Out:
# 161

# %%
len(df['BAS_ID'].unique())
# Out:
# 1335
